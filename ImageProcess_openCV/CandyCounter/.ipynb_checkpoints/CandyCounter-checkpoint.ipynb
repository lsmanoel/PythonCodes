# %%
# Adaptado de http://docs.opencv.org/3.2.0/df/d9d/tutorial_py_colorspaces.html
import numpy as np
import cv2

# img_BGR = cv2.imread("mms.jpg") #obtida de http://blogs.mathworks.com/images/steve/2010/mms.jpg
img_BGR = cv2.imread("balas_s.png")
img_buffer = img_BGR

# kernel = np.ones((5,5), np.uint8)
# img_buffer = cv2.erode(img_BGR, kernel,iterations = 1)
# img_buffer = cv2.dilate(img_buffer, kernel,iterations = 1)

# Convert BGR to HSV
img_HSV = cv2.cvtColor(img_buffer, cv2.COLOR_BGR2HSV)
# -----------------------------------------------------------------------------------------------------------------------

# define range of blue color in HSV
# importante: faixa da componente H no OpenCV: [0, 179]

red = 0

green = red + 60
if green > 179:
    green = green - 180

blue = green + 60
if blue > 179:
    blue = blue - 180
    
    
thres=31
lower_blue = np.array([blue-thres, 50, 50])
upper_blue = np.array([blue+thres, 255, 255])

lower_green = np.array([green-thres, 50, 40])
upper_green = np.array([green+thres, 255, 255])

lower_red = np.array([red-thres, 50, 50])
upper_red = np.array([red+thres, 255, 255])

# Threshold the HSV image to get only blue colors
mask_blue = cv2.inRange(img_HSV, lower_blue, upper_blue)
mask_green = cv2.inRange(img_HSV, lower_green, upper_green)
mask_red = cv2.inRange(img_HSV, lower_red, upper_red)

# mask = mask_blue;
mask = mask_green;
# mask = mask_red;

kernel = np.ones((5,5), np.uint8)
erosion = cv2.erode(mask, kernel, iterations = 3)
#erosion=mask

# Bitwise-AND mask and original image
imgRes = cv2.bitwise_and(img_BGR, img_BGR, mask= erosion)

# find all blobs and label them
n, labels, stats, centroids = cv2.connectedComponentsWithStats(erosion)
print centroids
print stats
font = cv2.FONT_HERSHEY_SIMPLEX

for n in range(1,len(stats)): #o primeiro (índice 0) é a imagem toda, então, desconsiderar
    cv2.rectangle(imgRes, (stats[n][0],stats[n][1]), (stats[n][0]+stats[n][2],stats[n][1]+stats[n][3]),(255,255,255),2)
    cv2.putText(imgRes, str(n),(stats[n][0], stats[n][1]), font, 1,(255, 255, 255), 2, cv2.LINE_AA)
    cv2.circle(imgRes, (int(centroids[n][0]), int(centroids[n][1])), 3, (0, 0, 255), -1)
    
cv2.putText(imgRes,'Total: '+str(n),(0, stats[0][3]), font, 1,(255,255,255),2,cv2.LINE_AA)
#cv2.imwrite('colorlabels.jpg',res) #para gravar a imagem
cv2.imshow('img_BGR', img_BGR)
cv2.imshow('img_buffer', img_buffer)
cv2.imshow('erosion', erosion)
cv2.imshow('imgRes', imgRes)

cv2.imwrite( "imgOut_BGR.jpg", img_BGR);
cv2.imwrite('img_buffer.jpg', img_buffer)
cv2.imwrite( "imgOut_erosion.jpg", erosion);
cv2.imwrite( "imgOut_imgRes.jpg", imgRes);
# -----------------------------------------------------------------------------------------------------------------------
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[248.52668979 251.77510683]
#  [336.93516699  79.97937132]
#  [149.13106796 117.56218215]
#  [180.          75.        ]
#  [316.61875428 148.19712526]
#  [397.11465572 161.25078964]
#  [363.46153846 124.53846154]
#  [ 86.83900227 183.08843537]
#  [134.07537688 180.36180905]
#  [192.83050847 186.37288136]
#  [133.74193548 296.59677419]
#  [173.90978887 353.94721689]
#  [357.72495088 314.13752456]
#  [103.21794872 303.88461538]
#  [ 94.         311.        ]
#  [304.1294964  328.89208633]
#  [117.5        323.        ]
#  [132.17391304 329.1884058 ]
#  [429.81081081 342.59459459]
#  [372.28241895 363.3915212 ]
#  [ 87.82191781 343.93150685]
#  [199.33333333 350.80952381]
#  [ 91.27707006 367.17515924]
#  [207.69662921 376.93820225]
#  [416.90787717 408.93991989]
#  [161.42727273 407.96363636]
#  [103.96646796 428.07675112]
#  [192.18181818 419.87878788]
#  [369.45794393 455.00934579]]
# [[     0      0    500    500 231212]
#  [   313     55     52     54   1018]
#  [    80     62    128    100   4326]
#  [   180     75      1      1      1]
#  [   281    100     77     99   2922]
#  [   342    115    100    109   3166]
#  [   360    123      8      3     13]
#  [    67    163     49     53    441]
#  [   125    169     27     24    199]
#  [   190    180      7     13     59]
#  [   129    291     10     12     62]
#  [   157    296     36    106   1042]
#  [   338    298     41     29    509]
#  [    95    300     16      9     78]
#  [    94    310      1      3      3]
#  [   289    314     26     32    139]
#  [   117    323      2      1      2]
#  [   120    324     25     13    207]
#  [   427    335      6     15     37]
#  [   321    336    100     54   1604]
#  [    80    341     16      6     73]
#  [   197    349      7      4     21]
#  [    74    359     36     18    314]
#  [   202    366     15     20    178]
#  [   404    386     29     42    749]
#  [   154    401     14     14    110]
#  [    79    402     57     47   1342]
#  [   187    412     11     17     66]
#  [   363    451     16     10    107]]
